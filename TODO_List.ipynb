# %% [markdown]
# ## TODO List Rest Of project

# %% [markdown]
# ### Writing section

# %% [markdown]
# #### Target for writing - **High level** Date(ASAP)  - **Conference Paper** (Date:30/06) - ** Journal Paper** (Date: 01/10)
# [**Aliz**] Define document outline (Intro, Method, FPGA Design, Results, Discussion)
# - [***ALIZ***] Review Paper Date(31/07)
# - ***Two paper***:  1- Non-stopping Piplining  2- Overall paper
# - [**ALIZ**] Write problem statement QAOA + MaxCut target use case
# - [**Hiroki**] Write the document for the remainder section why  is required.
# - [**Hiroki**] Documentation for Normalisation of **Gamma** and **H** in Pyhton
# - [**Hiroki & ALIZ**] Add FPGA architecture description with block-level explanation
# - [**Aliz**] Write limitations and future work outline
# - [ ] Compare CPU/GPU/FPGA outcomes in one concise subsection

# %% [markdown]
# ### Programming Section

# %% [markdown]
# - [**Aliz**] Normalisation of **Gamma** and **H** in Pyhton (date: 15/06)
# - [**Aliz**] Integerating FPGA simulation into the Python section of Objective function (date: 15/06)
#          - Need to update **tb** file for new gen_cost.sv (check latency, accurate result, must be range of <=31 )
#          - Run program with new integerated with FPGA on real board -> need to update copute timing in FPGADRIVER class (Hiroki) ( need exact latency of gen_cost)
#          - add function to to create all_tet_cmd.sv file
#
#
#
#
# - [Hiroki] Add **Reminder method** in both FPGA and Python (date: 15/06)
#
# **after these steps start write High-level documentations & Conference Paper ***
#
# - [**Hiroki**] Work on the optimise protocole such as ***SPI*** (date: 31/07)
# - [Hiroki] Parallesisation of Local and Global qubit on FPGA board (QAOA_system.sv, ADD_version.sv) (date: 31/07)
# - [**Aliz**] Define Python ***Fixed-point*** code as grand truth for FPGA fixed-point arthemetic (date: 31/07)
# - [] finish with evaluating results
# - []By the end of the Sep finsihe Joaurnal Paper
# - [***Dr Pourabdollah***] Funding (15/07)

# %% [markdown]
# ## Required Stuff

# %% [markdown]
# - [**DONE**] Fans for FPGA board 8x
